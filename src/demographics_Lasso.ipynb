# %%
import pandas as pd
X_train = pd.read_csv(r"/workspaces/regularized-linera-regression/data/interim/X_train.csv")
X_test = pd.read_csv(r"/workspaces/regularized-linera-regression/data/interim/X_test.csv")
X_train
# Out:
#       Median_Household_Income_2018  Percent of Population Aged 60+  \
# 0                          61773.0                            21.8
# 1                          60862.0                            18.1
# 2                          44041.0                            27.8
# 3                          46628.0                            17.4
# 4                          43478.0                            22.5
# ...                            ...                             ...
# 2507                       58806.0                            36.9
# 2508                       41829.0                            26.3
# 2509                       50374.0                            27.4
# 2510                       57494.0                            24.9
# 2511                       43226.0                            24.4
#
#       STATE_NAME  anycondition_prevalence  Obesity_prevalence  \
# 0             50                     42.6                32.6
# 1             32                     34.3                25.4
# 2             43                     53.0                38.2
# 3             10                     47.6                37.4
# 4             24                     50.4                38.6
# ...          ...                      ...                 ...
# 2507          41                     44.6                33.1
# 2508          42                     53.4                37.4
# 2509          22                     49.7                38.6
# 2510          23                     44.6                37.3
# 2511          43                     52.9                41.1
#
#       COPD_prevalence  diabetes_prevalence  CKD_prevalence  \
# 0                 7.7                 10.7             3.0
# 1                 6.6                 11.6             3.2
# 2                 9.7                 13.8             3.6
# 3                 7.6                 14.3             3.4
# 4                 9.8                 15.1             3.6
# ...               ...                  ...             ...
# 2507              7.1                 12.6             3.7
# 2508             13.3                 15.2             3.8
# 2509             11.3                 13.7             3.8
# 2510              6.1                  9.7             2.9
# 2511             10.0                 15.7             4.0
#
#       Active Physicians per 100000 Population 2018 (AAMC)  \
# 0                                                 207.9
# 1                                                 375.1
# 2                                                 224.8
# 3                                                 228.7
# 4                                                 191.3
# ...                                                 ...
# 2507                                              240.4
# 2508                                              253.1
# 2509                                              287.0
# 2510                                              302.7
# 2511                                              224.8
#
#       Total Active Patient Care Physicians per 100000 Population 2018 (AAMC)  \
# 0                                                 199.6
# 1                                                 304.1
# 2                                                 199.9
# 3                                                 202.9
# 4                                                 174.8
# ...                                                 ...
# 2507                                              219.1
# 2508                                              225.8
# 2509                                              249.7
# 2510                                              265.0
# 2511                                              199.9
#
#       Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)  \
# 0                                                  76.2
# 1                                                  94.8
# 2                                                  66.5
# 3                                                  71.9
# 4                                                  61.2
# ...                                                 ...
# 2507                                               84.8
# 2508                                               77.8
# 2509                                               87.6
# 2510                                               96.0
# 2511                                               66.5
#
#       Active General Surgeons per 100000 Population 2018 (AAMC)  \
# 0                                                  10.6
# 1                                                  10.2
# 2                                                   6.2
# 3                                                   7.0
# 4                                                   7.1
# ...                                                 ...
# 2507                                                9.2
# 2508                                                8.1
# 2509                                                7.9
# 2510                                                7.4
# 2511                                                6.2
#
#       Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)  \
# 0                                                  10.4
# 1                                                   7.4
# 2                                                   5.4
# 3                                                   6.1
# 4                                                   6.7
# ...                                                 ...
# 2507                                                8.6
# 2508                                                7.4
# 2509                                                6.7
# 2510                                                6.6
# 2511                                                5.4
#
#       Total nurse practitioners (2019)  Total physician assistants (2019)  \
# 0                             7.411168                           4.172021
# 1                            79.880000                          42.780000
# 2                             7.483505                           4.416780
# 3                            79.880000                          42.780000
# 4                            23.891148                           1.225481
# ...                                ...                                ...
# 2507                          4.678343                           3.995879
# 2508                         19.650999                           4.075155
# 2509                         11.773059                          10.076354
# 2510                          7.277016                           4.578456
# 2511                          8.112304                           4.787898
#
#       Total Hospitals (2019)  Internal Medicine Primary Care (2019)  \
# 0                   0.751482                               3.420539
# 1                  21.939678                              84.990000
# 2                   0.395341                               8.209178
# 3                   2.676293                              84.990000
# 4                   1.133856                              13.503194
# ...                      ...                                    ...
# 2507                0.563775                               3.352977
# 2508                0.393157                              12.263071
# 2509                0.383557                              19.750506
# 2510                0.320896                               8.123475
# 2511                0.428559                               8.898952
#
#       Family Medicine/General Practice Primary Care (2019)  \
# 0                                              9.743354
# 1                                             70.310000
# 2                                              7.265803
# 3                                             62.957492
# 4                                             12.564041
# ...                                                 ...
# 2507                                           5.350917
# 2508                                           8.499023
# 2509                                          16.042791
# 2510                                           8.858756
# 2511                                           7.876310
#
#       Total Specialist Physicians (2019)
# 0                              14.096767
# 1                             237.560000
# 2                              25.623823
# 3                             236.030608
# 4                              38.722901
# ...                                  ...
# 2507                            9.475376
# 2508                           34.539673
# 2509                           54.078829
# 2510                           23.708417
# 2511                           27.776858
#
# [2512 rows x 19 columns]

# %%
X_test
# Out:
#      Median_Household_Income_2018  Percent of Population Aged 60+  STATE_NAME  \
# 0                         48830.0                            23.1          43
# 1                         42720.0                            23.8          42
# 2                         49393.0                            23.1          25
# 3                         48029.0                            24.7          40
# 4                         37038.0                            22.3          17
# ..                            ...                             ...         ...
# 623                       47424.0                            27.3          35
# 624                       80737.0                            19.1          30
# 625                       45761.0                            28.8          38
# 626                       37823.0                            25.3           0
# 627                       53481.0                            28.3          23
#
#      anycondition_prevalence  Obesity_prevalence  COPD_prevalence  \
# 0                       52.2                40.5              8.7
# 1                       54.0                39.7             11.2
# 2                       44.3                35.0              9.9
# 3                       51.0                37.5              9.3
# 4                       55.5                38.8             14.3
# ..                       ...                 ...              ...
# 623                     51.1                37.3             11.0
# 624                     36.1                27.9              5.9
# 625                     46.7                33.2              9.9
# 626                     56.1                43.0             12.4
# 627                     41.0                30.4              6.4
#
#      diabetes_prevalence  CKD_prevalence  \
# 0                   15.9             3.8
# 1                   15.1             3.7
# 2                   12.1             3.3
# 3                   15.7             3.8
# 4                   16.3             3.8
# ..                   ...             ...
# 623                 13.5             3.6
# 624                 11.6             3.0
# 625                 13.1             3.5
# 626                 16.7             4.0
# 627                 10.5             3.2
#
#      Active Physicians per 100000 Population 2018 (AAMC)  \
# 0                                                224.8
# 1                                                253.1
# 2                                                273.1
# 3                                                229.5
# 4                                                230.9
# ..                                                 ...
# 623                                              292.7
# 624                                              306.5
# 625                                              320.5
# 626                                              217.1
# 627                                              302.7
#
#      Total Active Patient Care Physicians per 100000 Population 2018 (AAMC)  \
# 0                                                199.9
# 1                                                225.8
# 2                                                236.3
# 3                                                205.0
# 4                                                214.6
# ..                                                 ...
# 623                                              248.6
# 624                                              271.0
# 625                                              273.3
# 626                                              196.7
# 627                                              265.0
#
#      Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)  \
# 0                                                 66.5
# 1                                                 77.8
# 2                                                 79.0
# 3                                                 72.3
# 4                                                 72.9
# ..                                                 ...
# 623                                               83.7
# 624                                               87.5
# 625                                               88.2
# 626                                               71.2
# 627                                               96.0
#
#      Active General Surgeons per 100000 Population 2018 (AAMC)  \
# 0                                                  6.2
# 1                                                  8.1
# 2                                                  7.0
# 3                                                  7.0
# 4                                                  8.3
# ..                                                 ...
# 623                                                8.3
# 624                                                7.6
# 625                                                8.7
# 626                                                7.6
# 627                                                7.4
#
#      Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)  \
# 0                                                  5.4
# 1                                                  7.4
# 2                                                  6.3
# 3                                                  6.2
# 4                                                  7.6
# ..                                                 ...
# 623                                                7.1
# 624                                                6.7
# 625                                                7.2
# 626                                                6.9
# 627                                                6.6
#
#      Total nurse practitioners (2019)  Total physician assistants (2019)  \
# 0                           12.607719                           7.441101
# 1                           41.641100                           8.635385
# 2                           15.947055                           3.103539
# 3                           16.069803                           7.947772
# 4                           12.413880                           4.171808
# ..                                ...                                ...
# 623                         79.880000                          37.994112
# 624                         79.880000                          42.780000
# 625                         28.032647                          22.692714
# 626                         13.658016                           2.880189
# 627                         33.305001                          20.954396
#
#      Total Hospitals (2019)  Internal Medicine Primary Care (2019)  \
# 0                  0.666044                              13.830286
# 1                  0.833112                              25.985843
# 2                  0.569371                              17.785843
# 3                  0.522780                              16.191027
# 4                  0.444259                               8.356309
# ..                      ...                                    ...
# 623                3.296448                              84.990000
# 624                5.136823                              84.990000
# 625                0.796587                              41.534592
# 626                0.543737                              12.301366
# 627                1.468658                              37.179020
#
#      Family Medicine/General Practice Primary Care (2019)  \
# 0                                            12.240949
# 1                                            18.009703
# 2                                            12.768844
# 3                                            17.736638
# 4                                             8.038981
# ..                                                 ...
# 623                                          70.310000
# 624                                          70.310000
# 625                                          28.837240
# 626                                          10.056434
# 627                                          40.544213
#
#      Total Specialist Physicians (2019)
# 0                             43.169340
# 1                             73.190680
# 2                             50.706686
# 3                             48.883720
# 4                             27.315612
# ..                                  ...
# 623                          237.560000
# 624                          237.560000
# 625                          107.146919
# 626                           34.142347
# 627                          108.507229
#
# [628 rows x 19 columns]

# %%
y_train = pd.read_csv(r"/workspaces/regularized-linera-regression/data/interim/y_train.csv")
y_test = pd.read_csv(r"/workspaces/regularized-linera-regression/data/interim/y_test.csv")
y_test
# Out:
#      Heart disease_prevalence
# 0                         9.2
# 1                         9.5
# 2                         8.6
# 3                         8.9
# 4                        11.1
# ..                        ...
# 623                       9.5
# 624                       6.1
# 625                       9.2
# 626                      11.0
# 627                       7.7
#
# [628 rows x 1 columns]

# %%
y_train
# Out:
#       Heart disease_prevalence
# 0                          7.1
# 1                          6.3
# 2                          9.7
# 3                          6.9
# 4                          8.7
# ...                        ...
# 2507                       9.6
# 2508                      10.6
# 2509                      10.1
# 2510                       6.9
# 2511                      10.0
#
# [2512 rows x 1 columns]

# %%
from pickle import dump, load
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.feature_selection import f_regression, SelectKBest

mse_list = []

for p in [1, 0.8, 0.7, 0.6, 0.5]:
    selection_model = SelectKBest(f_regression, k = int(len(X_train.columns) * p))
    selection_model.fit(X_train, y_train)

    ix = selection_model.get_support()
    train_sel = pd.DataFrame(selection_model.transform(X_train), columns = X_train.columns.values[ix])

    

    model = Lasso(alpha = 3, max_iter = 300, random_state = 14)
    model.fit(train_sel, y_train)
    y_pred = model.predict(train_sel)
    mse = mean_squared_error(y_train, y_pred)
    mse_list.append(mse)


best_mse = mse_list.index(max(mse_list))
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/vscode/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/vscode/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/vscode/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/vscode/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
best_index=int(len(X_train.columns)*[1, 0.8, 0.7, 0.6, 0.5][best_mse])
best_index
# Out:
# 19

# %%
dump(selection_model, open(r"/workspaces/regularized-linera-regression/models/selection_model.pk", "wb"))

# %%
from sklearn.feature_selection import f_regression, SelectKBest

selection_model = SelectKBest(f_regression, k = best_index)
selection_model.fit(X_train, y_train)
ix = selection_model.get_support()
X_train_sel = pd.DataFrame(selection_model.transform(X_train), columns = X_train.columns.values[ix])
X_test_sel = pd.DataFrame(selection_model.transform(X_test), columns = X_test.columns.values[ix])




X_train_sel
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#       Median_Household_Income_2018  Percent of Population Aged 60+  \
# 0                          61773.0                            21.8
# 1                          60862.0                            18.1
# 2                          44041.0                            27.8
# 3                          46628.0                            17.4
# 4                          43478.0                            22.5
# ...                            ...                             ...
# 2507                       58806.0                            36.9
# 2508                       41829.0                            26.3
# 2509                       50374.0                            27.4
# 2510                       57494.0                            24.9
# 2511                       43226.0                            24.4
#
#       STATE_NAME  anycondition_prevalence  Obesity_prevalence  \
# 0           50.0                     42.6                32.6
# 1           32.0                     34.3                25.4
# 2           43.0                     53.0                38.2
# 3           10.0                     47.6                37.4
# 4           24.0                     50.4                38.6
# ...          ...                      ...                 ...
# 2507        41.0                     44.6                33.1
# 2508        42.0                     53.4                37.4
# 2509        22.0                     49.7                38.6
# 2510        23.0                     44.6                37.3
# 2511        43.0                     52.9                41.1
#
#       COPD_prevalence  diabetes_prevalence  CKD_prevalence  \
# 0                 7.7                 10.7             3.0
# 1                 6.6                 11.6             3.2
# 2                 9.7                 13.8             3.6
# 3                 7.6                 14.3             3.4
# 4                 9.8                 15.1             3.6
# ...               ...                  ...             ...
# 2507              7.1                 12.6             3.7
# 2508             13.3                 15.2             3.8
# 2509             11.3                 13.7             3.8
# 2510              6.1                  9.7             2.9
# 2511             10.0                 15.7             4.0
#
#       Active Physicians per 100000 Population 2018 (AAMC)  \
# 0                                                 207.9
# 1                                                 375.1
# 2                                                 224.8
# 3                                                 228.7
# 4                                                 191.3
# ...                                                 ...
# 2507                                              240.4
# 2508                                              253.1
# 2509                                              287.0
# 2510                                              302.7
# 2511                                              224.8
#
#       Total Active Patient Care Physicians per 100000 Population 2018 (AAMC)  \
# 0                                                 199.6
# 1                                                 304.1
# 2                                                 199.9
# 3                                                 202.9
# 4                                                 174.8
# ...                                                 ...
# 2507                                              219.1
# 2508                                              225.8
# 2509                                              249.7
# 2510                                              265.0
# 2511                                              199.9
#
#       Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)  \
# 0                                                  76.2
# 1                                                  94.8
# 2                                                  66.5
# 3                                                  71.9
# 4                                                  61.2
# ...                                                 ...
# 2507                                               84.8
# 2508                                               77.8
# 2509                                               87.6
# 2510                                               96.0
# 2511                                               66.5
#
#       Active General Surgeons per 100000 Population 2018 (AAMC)  \
# 0                                                  10.6
# 1                                                  10.2
# 2                                                   6.2
# 3                                                   7.0
# 4                                                   7.1
# ...                                                 ...
# 2507                                                9.2
# 2508                                                8.1
# 2509                                                7.9
# 2510                                                7.4
# 2511                                                6.2
#
#       Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)  \
# 0                                                  10.4
# 1                                                   7.4
# 2                                                   5.4
# 3                                                   6.1
# 4                                                   6.7
# ...                                                 ...
# 2507                                                8.6
# 2508                                                7.4
# 2509                                                6.7
# 2510                                                6.6
# 2511                                                5.4
#
#       Total nurse practitioners (2019)  Total physician assistants (2019)  \
# 0                             7.411168                           4.172021
# 1                            79.880000                          42.780000
# 2                             7.483505                           4.416780
# 3                            79.880000                          42.780000
# 4                            23.891148                           1.225481
# ...                                ...                                ...
# 2507                          4.678343                           3.995879
# 2508                         19.650999                           4.075155
# 2509                         11.773059                          10.076354
# 2510                          7.277016                           4.578456
# 2511                          8.112304                           4.787898
#
#       Total Hospitals (2019)  Internal Medicine Primary Care (2019)  \
# 0                   0.751482                               3.420539
# 1                  21.939678                              84.990000
# 2                   0.395341                               8.209178
# 3                   2.676293                              84.990000
# 4                   1.133856                              13.503194
# ...                      ...                                    ...
# 2507                0.563775                               3.352977
# 2508                0.393157                              12.263071
# 2509                0.383557                              19.750506
# 2510                0.320896                               8.123475
# 2511                0.428559                               8.898952
#
#       Family Medicine/General Practice Primary Care (2019)  \
# 0                                              9.743354
# 1                                             70.310000
# 2                                              7.265803
# 3                                             62.957492
# 4                                             12.564041
# ...                                                 ...
# 2507                                           5.350917
# 2508                                           8.499023
# 2509                                          16.042791
# 2510                                           8.858756
# 2511                                           7.876310
#
#       Total Specialist Physicians (2019)
# 0                              14.096767
# 1                             237.560000
# 2                              25.623823
# 3                             236.030608
# 4                              38.722901
# ...                                  ...
# 2507                            9.475376
# 2508                           34.539673
# 2509                           54.078829
# 2510                           23.708417
# 2511                           27.776858
#
# [2512 rows x 19 columns]

# %%
X_test_sel
# Out:
#      Median_Household_Income_2018  Percent of Population Aged 60+  STATE_NAME  \
# 0                         48830.0                            23.1        43.0
# 1                         42720.0                            23.8        42.0
# 2                         49393.0                            23.1        25.0
# 3                         48029.0                            24.7        40.0
# 4                         37038.0                            22.3        17.0
# ..                            ...                             ...         ...
# 623                       47424.0                            27.3        35.0
# 624                       80737.0                            19.1        30.0
# 625                       45761.0                            28.8        38.0
# 626                       37823.0                            25.3         0.0
# 627                       53481.0                            28.3        23.0
#
#      anycondition_prevalence  Obesity_prevalence  COPD_prevalence  \
# 0                       52.2                40.5              8.7
# 1                       54.0                39.7             11.2
# 2                       44.3                35.0              9.9
# 3                       51.0                37.5              9.3
# 4                       55.5                38.8             14.3
# ..                       ...                 ...              ...
# 623                     51.1                37.3             11.0
# 624                     36.1                27.9              5.9
# 625                     46.7                33.2              9.9
# 626                     56.1                43.0             12.4
# 627                     41.0                30.4              6.4
#
#      diabetes_prevalence  CKD_prevalence  \
# 0                   15.9             3.8
# 1                   15.1             3.7
# 2                   12.1             3.3
# 3                   15.7             3.8
# 4                   16.3             3.8
# ..                   ...             ...
# 623                 13.5             3.6
# 624                 11.6             3.0
# 625                 13.1             3.5
# 626                 16.7             4.0
# 627                 10.5             3.2
#
#      Active Physicians per 100000 Population 2018 (AAMC)  \
# 0                                                224.8
# 1                                                253.1
# 2                                                273.1
# 3                                                229.5
# 4                                                230.9
# ..                                                 ...
# 623                                              292.7
# 624                                              306.5
# 625                                              320.5
# 626                                              217.1
# 627                                              302.7
#
#      Total Active Patient Care Physicians per 100000 Population 2018 (AAMC)  \
# 0                                                199.9
# 1                                                225.8
# 2                                                236.3
# 3                                                205.0
# 4                                                214.6
# ..                                                 ...
# 623                                              248.6
# 624                                              271.0
# 625                                              273.3
# 626                                              196.7
# 627                                              265.0
#
#      Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)  \
# 0                                                 66.5
# 1                                                 77.8
# 2                                                 79.0
# 3                                                 72.3
# 4                                                 72.9
# ..                                                 ...
# 623                                               83.7
# 624                                               87.5
# 625                                               88.2
# 626                                               71.2
# 627                                               96.0
#
#      Active General Surgeons per 100000 Population 2018 (AAMC)  \
# 0                                                  6.2
# 1                                                  8.1
# 2                                                  7.0
# 3                                                  7.0
# 4                                                  8.3
# ..                                                 ...
# 623                                                8.3
# 624                                                7.6
# 625                                                8.7
# 626                                                7.6
# 627                                                7.4
#
#      Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)  \
# 0                                                  5.4
# 1                                                  7.4
# 2                                                  6.3
# 3                                                  6.2
# 4                                                  7.6
# ..                                                 ...
# 623                                                7.1
# 624                                                6.7
# 625                                                7.2
# 626                                                6.9
# 627                                                6.6
#
#      Total nurse practitioners (2019)  Total physician assistants (2019)  \
# 0                           12.607719                           7.441101
# 1                           41.641100                           8.635385
# 2                           15.947055                           3.103539
# 3                           16.069803                           7.947772
# 4                           12.413880                           4.171808
# ..                                ...                                ...
# 623                         79.880000                          37.994112
# 624                         79.880000                          42.780000
# 625                         28.032647                          22.692714
# 626                         13.658016                           2.880189
# 627                         33.305001                          20.954396
#
#      Total Hospitals (2019)  Internal Medicine Primary Care (2019)  \
# 0                  0.666044                              13.830286
# 1                  0.833112                              25.985843
# 2                  0.569371                              17.785843
# 3                  0.522780                              16.191027
# 4                  0.444259                               8.356309
# ..                      ...                                    ...
# 623                3.296448                              84.990000
# 624                5.136823                              84.990000
# 625                0.796587                              41.534592
# 626                0.543737                              12.301366
# 627                1.468658                              37.179020
#
#      Family Medicine/General Practice Primary Care (2019)  \
# 0                                            12.240949
# 1                                            18.009703
# 2                                            12.768844
# 3                                            17.736638
# 4                                             8.038981
# ..                                                 ...
# 623                                          70.310000
# 624                                          70.310000
# 625                                          28.837240
# 626                                          10.056434
# 627                                          40.544213
#
#      Total Specialist Physicians (2019)
# 0                             43.169340
# 1                             73.190680
# 2                             50.706686
# 3                             48.883720
# 4                             27.315612
# ..                                  ...
# 623                          237.560000
# 624                          237.560000
# 625                          107.146919
# 626                           34.142347
# 627                          108.507229
#
# [628 rows x 19 columns]

# %%
X_train_sel.to_csv(r"/workspaces/regularized-linera-regression/data/processed/norm_train_X_sel.csv", index=False)
X_test_sel.to_csv(r"/workspaces/regularized-linera-regression/data/processed/norm_test_X_sel.csv", index=False)

# %%
from sklearn.linear_model import Lasso

model = Lasso(alpha = 1, max_iter = 100, random_state = 14)
model
# Out:
# Lasso(alpha=1, max_iter=100, random_state=14)

# %%
model.fit(X_train_sel, y_train)
# Out:
# Lasso(alpha=1, max_iter=100, random_state=14)

# %%
print(f"Intercepto (a): {model.intercept_}")
print(f"Coeficientes (b1, b2, b3, b4): {model.coef_}")
# Out:
# Intercepto (a): [4.17922693]
# Coeficientes (b1, b2, b3, b4): [-4.48926702e-05  9.46987351e-02  0.00000000e+00  9.79070812e-02
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  5.53119880e-05 -0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -1.89323784e-03]

# %%
y_pred = model.predict(X_train_sel)
y_pred
# Out:
# array([7.62569784, 6.08629202, 9.98635385, ..., 9.28995816, 8.29259408,
#        9.68709877])

# %%
from sklearn.metrics import mean_squared_error, r2_score

mean_squared_error(y_train, y_pred)
# Out:
# 0.5503953187030692

# %%
r2_score(y_train, y_pred)
# Out:
# 0.8212057240667573

# %%
y_pred = model.predict(X_test_sel)
y_pred
# Out:
# array([ 9.2147353 ,  9.67614642,  8.40373815,  9.27418722, 10.02227201,
#         9.80010203,  9.00984375,  6.21127392,  8.4021042 ,  9.95506029,
#         8.38977055,  8.77507929,  9.25770086, 10.13038082, 10.01297431,
#         9.63299249,  9.23411977,  9.04089258,  9.98892948,  8.18335369,
#         8.66466927,  7.87699677,  8.4202985 ,  5.78276375,  7.90831221,
#         8.72536561, 10.82630853, 10.1448316 ,  8.50359852,  9.02843148,
#         7.91604715,  5.97077525,  9.26435045,  8.71798804,  3.92565756,
#         9.10719389,  9.63563762, 11.02203537,  8.63214609,  9.5492146 ,
#         6.34470292,  7.67815509,  9.34961331,  9.03035723,  9.89384016,
#        10.49836744,  9.90721528,  9.04452724,  8.92979354,  9.13444909,
#         8.99737674,  9.48577199,  7.01755053,  5.97745911,  8.34131507,
#         9.71147705, 10.80102106,  9.79212259,  7.53889418,  9.85021885,
#         7.86731811,  8.79889666, 10.68459381, 10.04825109,  5.28753273,
#         7.72092568,  9.93174361,  8.21490694,  7.93713781,  9.37055836,
#         8.52864877,  4.01477754,  8.54587579,  8.23086439,  6.31117352,
#        10.55087264, 10.35854341,  7.99805129, 10.19985896,  6.91611525,
#         7.68475911,  9.82379423,  9.64615593, 11.53833046,  5.84992385,
#         8.37903905,  8.52523434,  8.4974478 ,  8.23832155,  8.6782584 ,
#        10.08623155,  9.61927946,  8.89871378,  9.5692689 ,  7.24186348,
#         7.4169205 ,  8.04023484,  9.13507514,  9.18708998,  7.89909758,
#        10.52666202,  8.29567876,  9.99593514,  9.25104338, 10.11643618,
#         8.69242615,  2.52663308,  9.32498443,  9.68683933,  8.20732553,
#         7.63290091,  9.00758732,  7.84535369,  9.90253389, 10.63795286,
#         7.57056536,  8.93028817,  9.57862439,  8.54887374,  9.83755013,
#         9.51879569,  7.50375971,  6.06137359,  8.91505334,  9.90981036,
#         8.7820222 ,  7.06695313,  8.44067115, 10.34674107, 11.66277737,
#         9.98449134, 10.09591334, 10.70012315,  9.87787295, 10.11262264,
#         6.93125818,  8.81342756,  8.36528137, 10.05745425,  8.01002157,
#        10.51117055,  4.93435544,  8.92098521,  9.43644045,  8.005044  ,
#         6.8473419 ,  4.99552252,  8.58785791,  9.26414735,  7.66584216,
#         5.88971561,  9.38248206,  6.95049708,  9.44270443,  9.65904122,
#         9.78985733,  9.36794728, 10.70439068,  8.47254923,  9.82899435,
#         8.76472961, 10.65524552,  9.46029779,  7.36704057,  9.47092122,
#         8.0924925 ,  7.92646085,  8.89240391,  5.17871033,  8.60281754,
#         7.16009199,  8.45596416,  5.02693136, 10.15854199,  9.54992355,
#        10.38995983,  7.19746794,  9.16471778,  8.39593847,  5.73364912,
#         8.25430757,  7.53707345,  9.46275923, 10.69102805,  7.46399008,
#         7.04622909,  7.88958368,  8.2409567 ,  7.93221475,  8.8800202 ,
#        11.3143131 ,  6.77265805,  4.72616317,  9.87587341, 10.37390005,
#         8.62584678, 11.11753674,  9.04000368,  9.81101184,  9.17242616,
#         9.64693473,  9.18591119,  7.52200974,  9.55664452, 10.43885281,
#         9.08935052,  9.57695519,  7.61844091,  7.00024012,  8.39766648,
#         8.63832739, 10.7292029 ,  9.47132098, 10.07373534,  6.17423482,
#         8.51426614,  8.89856346,  6.78383807,  5.94925311,  9.77023529,
#         7.60107774,  7.65704411,  8.66874196,  9.20255723,  5.46315086,
#         9.23673988, 10.315957  ,  8.28171425])

# %%
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt

print(f"Error cuadrático medio: {sqrt(mean_squared_error(y_test, y_pred))}")
print(f"Coeficiente de determinación: {r2_score(y_test, y_pred)}")
# Out:
# Error cuadrático medio: 0.6894364933118479
# Coeficiente de determinación: 0.8488174751229934

# %%
dump(model, open(r"/workspaces/regularized-linera-regression/models/lasso_medical_insurance_model.pk", "wb"))
