# %%
import pandas as pd
total_data=pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/regularized-linear-regression-project-tutorial/main/demographic_health_data.csv")

# %%
total_data.to_csv('/workspaces/regularized-linera-regression/data/raw/total_data')

# %%
total_data
# Out:
#        fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0      1001    55601   6787               12.206615    7637
# 1      1003   218022  24757               11.355276   26913
# 2      1005    24881   2732               10.980266    2960
# 3      1007    22400   2456               10.964286    2596
# 4      1009    57840   7095               12.266598    7570
# ...     ...      ...    ...                     ...     ...
# 3135  56037    43051   6104               14.178532    6326
# 3136  56039    23081   2384               10.328842    2185
# 3137  56041    20299   3121               15.375142    3205
# 3138  56043     7885    858               10.881420    1113
# 3139  56045     6967    780               11.195637     779
#
#       10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                    13.735364   6878                 12.370281   7089
# 1                    12.344167  23579                 10.814964  25213
# ...

# %%
total_data.describe()
# Out:
#                fips       TOT_POP           0-9  0-9 y/o % of total pop  \
# count   3140.000000  3.140000e+03  3.140000e+03             3140.000000
# mean   30401.640764  1.041894e+05  1.274030e+04               11.871051
# std    15150.559265  3.335834e+05  4.180730e+04                2.124081
# min     1001.000000  8.800000e+01  0.000000e+00                0.000000
# 25%    18180.500000  1.096325e+04  1.280500e+03               10.594639
# 50%    29178.000000  2.580050e+04  3.057000e+03               11.802727
# 75%    45081.500000  6.791300e+04  8.097000e+03               12.951840
# max    56045.000000  1.010552e+07  1.208253e+06               25.460677
#
#              19-Oct  10-19 y/o % of total pop         20-29  \
# count  3.140000e+03               3140.000000  3.140000e+03
# mean   1.336798e+04                 12.694609  1.446933e+04
# std    4.228439e+04                  1.815044  4.957773e+04
# min    0.000000e+00                  0.000000  0.000000e+00
# ...

# %%
total_data['Total Active Patient Care Physicians per 100000 Population 2018 (AAMC)']
# Out:
# 0       196.7
# 1       196.7
# 2       196.7
# 3       196.7
# 4       196.7
#         ...
# 3135    199.6
# 3136    199.6
# 3137    199.6
# 3138    199.6
# 3139    199.6
# Name: Total Active Patient Care Physicians per 100000 Population 2018 (AAMC), Length: 3140, dtype: float64

# %%
cols=["Median_Household_Income_2018", "Percent of Population Aged 60+", "STATE_NAME", "anycondition_prevalence",
      "Obesity_prevalence", "Heart disease_prevalence",  "COPD_prevalence", "diabetes_prevalence", "CKD_prevalence",
     "Active Physicians per 100000 Population 2018 (AAMC)","Total Active Patient Care Physicians per 100000 Population 2018 (AAMC)",
     "Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)", "Active General Surgeons per 100000 Population 2018 (AAMC)",
     "Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)","Total nurse practitioners (2019)",
     "Total physician assistants (2019)","Total Hospitals (2019)","Internal Medicine Primary Care (2019)",
     "Family Medicine/General Practice Primary Care (2019)","Total Specialist Physicians (2019)"]

# %%
total_data=total_data[cols]

# %%
total_data
# Out:
#       Median_Household_Income_2018  Percent of Population Aged 60+ STATE_NAME  \
# 0                            59338                            19.1    Alabama
# 1                            57588                            26.3    Alabama
# 2                            34382                            23.5    Alabama
# 3                            46064                            21.1    Alabama
# 4                            50412                            23.6    Alabama
# ...                            ...                             ...        ...
# 3135                         73315                            15.8    Wyoming
# 3136                         99087                            18.7    Wyoming
# 3137                         63401                            17.1    Wyoming
# 3138                         55190                            26.7    Wyoming
# 3139                         54319                            29.1    Wyoming
#
# ...

# %%
#total_data=total_data.groupby("STATE_NAME").mean()

# %%
total_data.isnull().sum().sort_values(ascending=False)
# Out:
# Median_Household_Income_2018                                                     0
# Percent of Population Aged 60+                                                   0
# Family Medicine/General Practice Primary Care (2019)                             0
# Internal Medicine Primary Care (2019)                                            0
# Total Hospitals (2019)                                                           0
# Total physician assistants (2019)                                                0
# Total nurse practitioners (2019)                                                 0
# Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)           0
# Active General Surgeons per 100000 Population 2018 (AAMC)                        0
# Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)    0
# Total Active Patient Care Physicians per 100000 Population 2018 (AAMC)           0
# ...

# %%
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Data columns (total 20 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   Median_Household_Income_2018                                                   3140 non-null   int64
#  1   Percent of Population Aged 60+                                                 3140 non-null   float64
#  2   STATE_NAME                                                                     3140 non-null   object
#  3   anycondition_prevalence                                                        3140 non-null   float64
#  4   Obesity_prevalence                                                             3140 non-null   float64
#  5   Heart disease_prevalence                                                       3140 non-null   float64
# ...

# %%
total_data.describe()
# Out:
#        Median_Household_Income_2018  Percent of Population Aged 60+  \
# count                   3140.000000                     3140.000000
# mean                   52767.083758                       24.736943
# std                    13907.992668                        5.564871
# min                        0.000000                        5.800000
# 25%                    43677.000000                       21.200000
# 50%                    50564.500000                       24.400000
# 75%                    58822.250000                       27.800000
# max                   140382.000000                       64.200000
#
#        anycondition_prevalence  Obesity_prevalence  Heart disease_prevalence  \
# count              3140.000000         3140.000000               3140.000000
# mean                 46.793917           35.019299                  8.607803
# std                   6.379448            4.517088                  1.758587
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

fig, axis = plt.subplots(4, 2, figsize = (10, 11))

# Crear una figura múltiple con histogramas y diagramas de caja
sns.histplot(ax = axis[0, 0], data = total_data, x = "Median_Household_Income_2018").set(xlabel = None)
sns.boxplot(ax = axis[1, 0], data = total_data, x = "Median_Household_Income_2018")
sns.histplot(ax = axis[0, 1], data = total_data, x = "Percent of Population Aged 60+").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[1, 1], data = total_data, x = "Percent of Population Aged 60+")
sns.histplot(ax = axis[2, 0], data = total_data, x = "anycondition_prevalence").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[3, 0], data = total_data, x = "anycondition_prevalence")
sns.histplot(ax = axis[2, 1], data = total_data, x = "Obesity_prevalence").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[3, 1], data = total_data, x = "Obesity_prevalence")

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
fig, axis = plt.subplots(4, 2, figsize = (10, 11))

# Crear una figura múltiple con histogramas y diagramas de caja
sns.histplot(ax = axis[0, 0], data = total_data, x = "Heart disease_prevalence").set(xlabel = None)
sns.boxplot(ax = axis[1, 0], data = total_data, x = "Heart disease_prevalence")
sns.histplot(ax = axis[0, 1], data = total_data, x = "COPD_prevalence").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[1, 1], data = total_data, x = "COPD_prevalence")
sns.histplot(ax = axis[2, 0], data = total_data, x = "diabetes_prevalence").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[3, 0], data = total_data, x = "diabetes_prevalence")
sns.histplot(ax = axis[2, 1], data = total_data, x = "CKD_prevalence").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[3, 1], data = total_data, x = "CKD_prevalence")

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
fig, axis = plt.subplots(4, 2, figsize = (10, 11))

# Crear una figura múltiple con histogramas y diagramas de caja
sns.histplot(ax = axis[0, 0], data = total_data, x = "Active Physicians per 100000 Population 2018 (AAMC)").set(xlabel = None)
sns.boxplot(ax = axis[1, 0], data = total_data, x = "Active Physicians per 100000 Population 2018 (AAMC)")
sns.histplot(ax = axis[0, 1], data = total_data, x = "Total Active Patient Care Physicians per 100000 Population 2018 (AAMC)").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[1, 1], data = total_data, x = "Total Active Patient Care Physicians per 100000 Population 2018 (AAMC)")
sns.histplot(ax = axis[2, 0], data = total_data, x = "Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[3, 0], data = total_data, x = "Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)")
sns.histplot(ax = axis[2, 1], data = total_data, x = "Active General Surgeons per 100000 Population 2018 (AAMC)").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[3, 1], data = total_data, x = "Active General Surgeons per 100000 Population 2018 (AAMC)")

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
fig, axis = plt.subplots(4, 2, figsize = (12, 8))

# Crear una figura múltiple con histogramas y diagramas de caja
sns.histplot(ax = axis[0, 0], data = total_data, x = "Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)").set(xlabel = None)
sns.boxplot(ax = axis[1, 0], data = total_data, x = "Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)")
sns.histplot(ax = axis[0, 1], data = total_data, x = "Total nurse practitioners (2019)").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[1, 1], data = total_data, x = "Total nurse practitioners (2019)")
sns.histplot(ax = axis[2, 0], data = total_data, x = "Total physician assistants (2019)").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[3, 0], data = total_data, x = "Total physician assistants (2019)")
sns.histplot(ax = axis[2, 1], data = total_data, x = "Total Hospitals (2019)").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[3, 1], data = total_data, x = "Total Hospitals (2019)")

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
fig, axis = plt.subplots(2, 3, figsize = (12, 7))

sns.histplot(ax = axis[0, 0], data = total_data, x = "Internal Medicine Primary Care (2019)").set(xlabel = None)
sns.boxplot(ax = axis[1, 0], data = total_data, x = "Internal Medicine Primary Care (2019)")
sns.histplot(ax = axis[0, 1], data = total_data, x = "Family Medicine/General Practice Primary Care (2019)").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[1, 1], data = total_data, x = "Family Medicine/General Practice Primary Care (2019)")
sns.histplot(ax = axis[0, 2], data = total_data, x = "Total Specialist Physicians (2019)").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[1, 2], data = total_data, x = "Total Specialist Physicians (2019)")

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
fig, axis = plt.subplots(2, 2, figsize = (14, 6))

# Crear un diagrama de dispersión múltiple
sns.regplot(ax = axis[0, 0], data = total_data, x = "Median_Household_Income_2018", y = "Heart disease_prevalence")
sns.heatmap(total_data[["Heart disease_prevalence", "Median_Household_Income_2018"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 0], cbar = False)
sns.regplot(ax = axis[0, 1], data = total_data, x = "anycondition_prevalence", y = "Heart disease_prevalence").set(ylabel=None)
sns.heatmap(total_data[["Heart disease_prevalence", "anycondition_prevalence"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 1])

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %% [markdown]
# Se puede ver una clara correlación negativa entre el ingreso medio y la enfermedad cardíaca, así como una relación postiva con la existencia de otras enfermedades

# %%
fig, axis = plt.subplots(2, 2, figsize = (12, 6))

# Crear un diagrama de dispersión múltiple
sns.regplot(ax = axis[0, 0], data = total_data, x = "Obesity_prevalence", y = "Heart disease_prevalence")
sns.heatmap(total_data[["Heart disease_prevalence", "Obesity_prevalence"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 0], cbar = False)
sns.regplot(ax = axis[0, 1], data = total_data, x = "COPD_prevalence", y = "Heart disease_prevalence").set(ylabel=None)
sns.heatmap(total_data[["Heart disease_prevalence", "COPD_prevalence"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 1])


# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
fig, axis = plt.subplots(2, 2, figsize = (12, 6))

sns.regplot(ax = axis[0, 0], data = total_data, x = "diabetes_prevalence", y = "Heart disease_prevalence")
sns.heatmap(total_data[["Heart disease_prevalence", "diabetes_prevalence"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 0], cbar = False)
sns.regplot(ax = axis[0, 1], data = total_data, x = "CKD_prevalence", y = "Heart disease_prevalence").set(ylabel=None)
sns.heatmap(total_data[["Heart disease_prevalence", "CKD_prevalence"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 1])

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
fig, axis = plt.subplots(2, 1, figsize = (10, 7))
sns.regplot(ax = axis[0], data = total_data, x = "Percent of Population Aged 60+", y = "Heart disease_prevalence")
sns.heatmap(total_data[["Heart disease_prevalence", "Percent of Population Aged 60+"]].corr(), annot = True, fmt = ".2f", ax = axis[1], cbar = False)
# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %% [markdown]
# En todos los gráficos anteriores se puede ver una evidente correlación positiva entre la existencia de otras enfermedades y la edad con la enfermedad cardíaca

# %%
fig, axis = plt.subplots(2, 3, figsize = (18, 12))

# Crear un diagrama de dispersión múltiple
sns.regplot(ax = axis[0, 0], data = total_data, x = "Active Physicians per 100000 Population 2018 (AAMC)", y = "Heart disease_prevalence")
sns.heatmap(total_data[["Heart disease_prevalence", "Active Physicians per 100000 Population 2018 (AAMC)"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 0], cbar = False)
sns.regplot(ax = axis[0, 1], data = total_data, x = "Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)", y = "Heart disease_prevalence").set(ylabel=None)
sns.heatmap(total_data[["Heart disease_prevalence", "Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 1])
sns.regplot(ax = axis[0, 2], data = total_data, x = "Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)", y = "Heart disease_prevalence").set(ylabel=None)
sns.heatmap(total_data[["Heart disease_prevalence", "Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 2])

# Ajustar el layout
#plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
fig, axis = plt.subplots(2, 3, figsize = (18, 12))

# Crear un diagrama de dispersión múltiple
sns.regplot(ax = axis[0, 0], data = total_data, x = "Active General Surgeons per 100000 Population 2018 (AAMC)", y = "Heart disease_prevalence")
sns.heatmap(total_data[["Heart disease_prevalence", "Active General Surgeons per 100000 Population 2018 (AAMC)"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 0], cbar = False)
sns.regplot(ax = axis[0, 1], data = total_data, x = "Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)", y = "Heart disease_prevalence").set(ylabel=None)
sns.heatmap(total_data[["Heart disease_prevalence", "Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 1])
sns.regplot(ax = axis[0, 2], data = total_data, x = "Total nurse practitioners (2019)", y = "Heart disease_prevalence").set(ylabel=None)
sns.heatmap(total_data[["Heart disease_prevalence", "Total nurse practitioners (2019)"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 2])

# Ajustar el layout
#plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
fig, axis = plt.subplots(2, 3, figsize = (18, 12))

# Crear un diagrama de dispersión múltiple
sns.regplot(ax = axis[0, 0], data = total_data, x = "Total physician assistants (2019)", y = "Heart disease_prevalence")
sns.heatmap(total_data[["Heart disease_prevalence", "Total physician assistants (2019)"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 0], cbar = False)
sns.regplot(ax = axis[0, 1], data = total_data, x = "Total Hospitals (2019)", y = "Heart disease_prevalence").set(ylabel=None)
sns.heatmap(total_data[["Heart disease_prevalence", "Total Hospitals (2019)"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 1])
sns.regplot(ax = axis[0, 2], data = total_data, x = "Internal Medicine Primary Care (2019)", y = "Heart disease_prevalence").set(ylabel=None)
sns.heatmap(total_data[["Heart disease_prevalence", "Internal Medicine Primary Care (2019)"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 2])

# Ajustar el layout
# plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
total_data.describe()
# Out:
#        Median_Household_Income_2018  Percent of Population Aged 60+  \
# count                   3140.000000                     3140.000000
# mean                   52767.083758                       24.736943
# std                    13907.992668                        5.564871
# min                        0.000000                        5.800000
# 25%                    43677.000000                       21.200000
# 50%                    50564.500000                       24.400000
# 75%                    58822.250000                       27.800000
# max                   140382.000000                       64.200000
#
#        anycondition_prevalence  Obesity_prevalence  Heart disease_prevalence  \
# count              3140.000000         3140.000000               3140.000000
# mean                 46.793917           35.019299                  8.607803
# std                   6.379448            4.517088                  1.758587
# ...

# %%
fig, axis = plt.subplots(2, 2, figsize = (12, 6))

sns.regplot(ax = axis[0, 0], data = total_data, x = "Family Medicine/General Practice Primary Care (2019)", y = "Heart disease_prevalence")
sns.heatmap(total_data[["Heart disease_prevalence", "Family Medicine/General Practice Primary Care (2019)"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 0], cbar = False)
sns.regplot(ax = axis[0, 1], data = total_data, x = "Total Specialist Physicians (2019)", y = "Heart disease_prevalence").set(ylabel=None)
sns.heatmap(total_data[["Heart disease_prevalence", "Total Specialist Physicians (2019)"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 1])

# Ajustar el layout
# plt.tight_layout()

# Mostrar el plot
plt.show()

# %% [markdown]
# En los gráficos medidos anteriormente se puede ver una relación negativa entre los servicios médicos prestados y la incidencia de enfermedades del corazón

# %%
media_por_grupo = total_data.groupby('STATE_NAME')['Heart disease_prevalence'].mean()
media_por_grupo=media_por_grupo.to_frame()
media_por_grupo
# Out:
#                       Heart disease_prevalence
# STATE_NAME
# Alabama                               9.616418
# Alaska                                7.448148
# Arizona                               9.000000
# Arkansas                             10.230667
# California                            6.901724
# Colorado                              6.976562
# Connecticut                           6.312500
# Delaware                              7.666667
# District of Columbia                  4.100000
# Florida                               9.598507
# Georgia                               8.625786
# Hawaii                                7.660000
# Idaho                                 8.175000
# Illinois                              8.043137
# Indiana                               8.095652
# Iowa                                  7.881818
# Kansas                                8.315238
# Kentucky                             10.523333
# Louisiana                             9.095313
# ...

# %%
plt.figure(figsize=(15, 6))
ax = sns.barplot(x=media_por_grupo.index, y='Heart disease_prevalence', data=media_por_grupo)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.set_xlabel('States', fontsize=14)  # Puedes ajustar la fuente según tus preferencias
ax.set_ylabel('Count', fontsize=14)

plt.title('Media de enfermedad cardíaca por estado')
plt.show()
# Out:
# /tmp/ipykernel_1321/506351642.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# %%
total_data["STATE_NAME"] = pd.factorize(total_data["STATE_NAME"])[0]
# Out:
# /tmp/ipykernel_1321/4163571534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_data["STATE_NAME"] = pd.factorize(total_data["STATE_NAME"])[0]

# %%
fig, axis = plt.subplots(figsize = (12, 6))

sns.heatmap(total_data[["STATE_NAME", "Heart disease_prevalence"]].corr(), annot = True, fmt = ".2f")

plt.tight_layout()

plt.show()

# %% [markdown]
# Se puede observar que apenas hay relación entre el estado y la enfermedad

# %%
cols=[str(i) for i in total_data.columns] 
cols
# Out:
# ['Median_Household_Income_2018',
#  'Percent of Population Aged 60+',
#  'STATE_NAME',
#  'anycondition_prevalence',
#  'Obesity_prevalence',
#  'Heart disease_prevalence',
#  'COPD_prevalence',
#  'diabetes_prevalence',
#  'CKD_prevalence',
#  'Active Physicians per 100000 Population 2018 (AAMC)',
#  'Total Active Patient Care Physicians per 100000 Population 2018 (AAMC)',
#  'Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)',
#  'Active General Surgeons per 100000 Population 2018 (AAMC)',
#  'Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)',
#  'Total nurse practitioners (2019)',
#  'Total physician assistants (2019)',
#  'Total Hospitals (2019)',
#  'Internal Medicine Primary Care (2019)',
#  'Family Medicine/General Practice Primary Care (2019)',
#  'Total Specialist Physicians (2019)']

# %%
fig, axis = plt.subplots(figsize = (15, 6))

sns.heatmap(total_data[cols].corr(), annot = True, fmt = ".2f")

#plt.tight_layout()

plt.show()

# %% [markdown]
# Se puede observar mucha correlación entre las variables que indican enfermedad

# %%
total_data.describe()
# Out:
#        Median_Household_Income_2018  Percent of Population Aged 60+  \
# count                   3140.000000                     3140.000000
# mean                   52767.083758                       24.736943
# std                    13907.992668                        5.564871
# min                        0.000000                        5.800000
# 25%                    43677.000000                       21.200000
# 50%                    50564.500000                       24.400000
# 75%                    58822.250000                       27.800000
# max                   140382.000000                       64.200000
#
#         STATE_NAME  anycondition_prevalence  Obesity_prevalence  \
# count  3140.000000              3140.000000         3140.000000
# mean     26.253503                46.793917           35.019299
# std      14.260381                 6.379448            4.517088
# min       0.000000                22.000000           15.200000
# ...

# %%
fig, axis = plt.subplots(2, 4, figsize = (15, 10))

sns.boxplot(ax = axis[0, 0], data = total_data, y = "Median_Household_Income_2018")
sns.boxplot(ax = axis[0, 1], data = total_data, y = "Percent of Population Aged 60+")
sns.boxplot(ax = axis[0, 2], data = total_data, y = "anycondition_prevalence")
sns.boxplot(ax = axis[0, 3], data = total_data, y = "Obesity_prevalence")

sns.boxplot(ax = axis[1, 0], data = total_data, y = "Heart disease_prevalence")
sns.boxplot(ax = axis[1, 1], data = total_data, y = "COPD_prevalence")
sns.boxplot(ax = axis[1, 2], data = total_data, y = "diabetes_prevalence")
sns.boxplot(ax = axis[1, 3], data = total_data, y = "CKD_prevalence")


plt.tight_layout()

plt.show()

# %%
total_data['Median_Household_Income_2018'].replace(0, total_data['Median_Household_Income_2018'].median(), inplace=True)
# Out:
# /tmp/ipykernel_1321/1469715176.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_data['Median_Household_Income_2018'].replace(0, total_data['Median_Household_Income_2018'].median(), inplace=True)

# %%
total_data.describe()
# Out:
#        Median_Household_Income_2018  Percent of Population Aged 60+  \
# count                   3140.000000                     3140.000000
# mean                   52783.187102                       24.736943
# std                    13876.113404                        5.564871
# min                    25385.000000                        5.800000
# 25%                    43680.500000                       21.200000
# 50%                    50564.750000                       24.400000
# 75%                    58822.250000                       27.800000
# max                   140382.000000                       64.200000
#
#         STATE_NAME  anycondition_prevalence  Obesity_prevalence  \
# count  3140.000000              3140.000000         3140.000000
# mean     26.253503                46.793917           35.019299
# std      14.260381                 6.379448            4.517088
# min       0.000000                22.000000           15.200000
# ...

# %%
fig, axis = plt.subplots(3, 4, figsize = (15, 10))

sns.boxplot(ax = axis[0, 0], data = total_data, y = "Active Physicians per 100000 Population 2018 (AAMC)")
sns.boxplot(ax = axis[0, 1], data = total_data, y = "Total Active Patient Care Physicians per 100000 Population 2018 (AAMC)")
sns.boxplot(ax = axis[0, 2], data = total_data, y = "Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)")
sns.boxplot(ax = axis[0, 3], data = total_data, y = "Active General Surgeons per 100000 Population 2018 (AAMC)")

sns.boxplot(ax = axis[1, 0], data = total_data, y = "Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)")
sns.boxplot(ax = axis[1, 1], data = total_data, y = "Total nurse practitioners (2019)")
sns.boxplot(ax = axis[1, 2], data = total_data, y = "Total physician assistants (2019)")
sns.boxplot(ax = axis[1, 3], data = total_data, y = "Total Hospitals (2019)")

sns.boxplot(ax = axis[2, 0], data = total_data, y = "Internal Medicine Primary Care (2019)")
sns.boxplot(ax = axis[2, 1], data = total_data, y = "Family Medicine/General Practice Primary Care (2019)")
sns.boxplot(ax = axis[2, 2], data = total_data, y = "Total Specialist Physicians (2019)")

fig.delaxes(axis[2, 3])
plt.tight_layout()

plt.show()

# %%
nurse_stats = total_data["Total nurse practitioners (2019)"].describe()
nurse_stats
# Out:
# count    3140.000000
# mean       52.698009
# std       153.878850
# min         0.025524
# 25%         5.439135
# 50%        13.076544
# 75%        35.215580
# max      3937.767709
# Name: Total nurse practitioners (2019), dtype: float64

# %%
stats=total_data.describe()

# %%
stats
# Out:
#        Median_Household_Income_2018  Percent of Population Aged 60+  \
# count                   3140.000000                     3140.000000
# mean                   52783.187102                       24.736943
# std                    13876.113404                        5.564871
# min                    25385.000000                        5.800000
# 25%                    43680.500000                       21.200000
# 50%                    50564.750000                       24.400000
# 75%                    58822.250000                       27.800000
# max                   140382.000000                       64.200000
#
#         STATE_NAME  anycondition_prevalence  Obesity_prevalence  \
# count  3140.000000              3140.000000         3140.000000
# mean     26.253503                46.793917           35.019299
# std      14.260381                 6.379448            4.517088
# min       0.000000                22.000000           15.200000
# ...

# %%
nurse_iqr = stats["Total nurse practitioners (2019)"]["75%"] - stats["Total nurse practitioners (2019)"]["25%"]
upper_limit = stats["Total nurse practitioners (2019)"]["75%"] + 1.5 * nurse_iqr
lower_limit = stats["Total nurse practitioners (2019)"]["25%"] - 1.5 * nurse_iqr

# %%
print(f"Los límites superior e inferior para la búsqueda de outliers son {round(upper_limit, 2)} y {round(lower_limit, 2)}, con un rango intercuartílico de {round(nurse_iqr, 2)}")
# Out:
# Los límites superior e inferior para la búsqueda de outliers son 79.88 y -39.23, con un rango intercuartílico de 29.78

# %%
total_data['Total nurse practitioners (2019)'] = total_data['Total nurse practitioners (2019)'].apply(lambda x: 79.88 if x > 80 else x)
total_data['Total nurse practitioners (2019)'] = total_data['Total nurse practitioners (2019)'].apply(lambda x: -39.23 if x < -39.23  else x)
# Out:
# /tmp/ipykernel_1321/2711965051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_data['Total nurse practitioners (2019)'] = total_data['Total nurse practitioners (2019)'].apply(lambda x: 79.88 if x > 80 else x)
# /tmp/ipykernel_1321/2711965051.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_data['Total nurse practitioners (2019)'] = total_data['Total nurse practitioners (2019)'].apply(lambda x: -39.23 if x < -39.23  else x)

# %%
pys_assist_iqr = stats["Total physician assistants (2019)"]["75%"] - stats["Total physician assistants (2019)"]["25%"]
upper_limit = stats["Total physician assistants (2019)"]["75%"] + 1.5 * pys_assist_iqr
lower_limit = stats["Total physician assistants (2019)"]["25%"] - 1.5 * pys_assist_iqr

# %%
print(f"Los límites superior e inferior para la búsqueda de outliers son {round(upper_limit, 2)} y {round(lower_limit, 2)}, con un rango intercuartílico de {round(pys_assist_iqr, 2)}")
# Out:
# Los límites superior e inferior para la búsqueda de outliers son 42.78 y -21.71, con un rango intercuartílico de 16.12

# %%
total_data['Total physician assistants (2019)'] = total_data['Total physician assistants (2019)'].apply(lambda x: 42.78 if x > 42.78 else x)
total_data['Total physician assistants (2019)'] = total_data['Total physician assistants (2019)'].apply(lambda x: -21.71 if x < -21.71 else x)
# Out:
# /tmp/ipykernel_1321/3327406477.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_data['Total physician assistants (2019)'] = total_data['Total physician assistants (2019)'].apply(lambda x: 42.78 if x > 42.78 else x)
# /tmp/ipykernel_1321/3327406477.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_data['Total physician assistants (2019)'] = total_data['Total physician assistants (2019)'].apply(lambda x: -21.71 if x < -21.71 else x)

# %%
internal_iqr = stats["Internal Medicine Primary Care (2019)"]["75%"] - stats["Internal Medicine Primary Care (2019)"]["25%"]
upper_limit = stats["Internal Medicine Primary Care (2019)"]["75%"] + 1.5 * internal_iqr
lower_limit = stats["Internal Medicine Primary Care (2019)"]["25%"] - 1.5 * internal_iqr

# %%
print(f"Los límites superior e inferior para la búsqueda de outliers son {round(upper_limit, 2)} y {round(lower_limit, 2)}, con un rango intercuartílico de {round(internal_iqr, 2)}")
# Out:
# Los límites superior e inferior para la búsqueda de outliers son 84.99 y -43.24, con un rango intercuartílico de 32.06

# %%
total_data['Internal Medicine Primary Care (2019)'] = total_data['Internal Medicine Primary Care (2019)'].apply(lambda x: 84.99 if x > 84.99 else x)
total_data['Internal Medicine Primary Care (2019)'] = total_data['Internal Medicine Primary Care (2019)'].apply(lambda x: -43.24 if x < -43.24 else x)
# Out:
# /tmp/ipykernel_1321/875722328.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_data['Internal Medicine Primary Care (2019)'] = total_data['Internal Medicine Primary Care (2019)'].apply(lambda x: 84.99 if x > 84.99 else x)
# /tmp/ipykernel_1321/875722328.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_data['Internal Medicine Primary Care (2019)'] = total_data['Internal Medicine Primary Care (2019)'].apply(lambda x: -43.24 if x < -43.24 else x)

# %%
fam_iqr = stats["Family Medicine/General Practice Primary Care (2019)"]["75%"] - stats["Family Medicine/General Practice Primary Care (2019)"]["25%"]
upper_limit = stats["Family Medicine/General Practice Primary Care (2019)"]["75%"] + 1.5 * fam_iqr
lower_limit = stats["Family Medicine/General Practice Primary Care (2019)"]["25%"] - 1.5 * fam_iqr

# %%
print(f"Los límites superior e inferior para la búsqueda de outliers son {round(upper_limit, 2)} y {round(lower_limit, 2)}, con un rango intercuartílico de {round(fam_iqr, 2)}")
# Out:
# Los límites superior e inferior para la búsqueda de outliers son 70.31 y -33.69, con un rango intercuartílico de 26.0

# %%
total_data['Family Medicine/General Practice Primary Care (2019)'] = total_data['Family Medicine/General Practice Primary Care (2019)'].apply(lambda x: 70.31 if x > 70.31 else x)
total_data['Family Medicine/General Practice Primary Care (2019)'] = total_data['Family Medicine/General Practice Primary Care (2019)'].apply(lambda x: -33.69 if x < -33.69 else x)
# Out:
# /tmp/ipykernel_1321/1243480263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_data['Family Medicine/General Practice Primary Care (2019)'] = total_data['Family Medicine/General Practice Primary Care (2019)'].apply(lambda x: 70.31 if x > 70.31 else x)
# /tmp/ipykernel_1321/1243480263.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
spec_iqr = stats["Total Specialist Physicians (2019)"]["75%"] - stats["Total Specialist Physicians (2019)"]["25%"]
upper_limit = stats["Total Specialist Physicians (2019)"]["75%"] + 1.5 * spec_iqr
lower_limit = stats["Total Specialist Physicians (2019)"]["25%"] - 1.5 * spec_iqr

# %%
print(f"Los límites superior e inferior para la búsqueda de outliers son {round(upper_limit, 2)} y {round(lower_limit, 2)}, con un rango intercuartílico de {round(spec_iqr, 2)}")
# Out:
# Los límites superior e inferior para la búsqueda de outliers son 237.56 y -118.95, con un rango intercuartílico de 89.13

# %%
total_data['Total Specialist Physicians (2019)'] = total_data['Total Specialist Physicians (2019)'].apply(lambda x: 237.56 if x > 237.56 else x)
total_data['Total Specialist Physicians (2019)'] = total_data['Total Specialist Physicians (2019)'].apply(lambda x: -118.95 if x < -118.95 else x)
# Out:
# /tmp/ipykernel_1321/351097966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_data['Total Specialist Physicians (2019)'] = total_data['Total Specialist Physicians (2019)'].apply(lambda x: 237.56 if x > 237.56 else x)
# /tmp/ipykernel_1321/351097966.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_data['Total Specialist Physicians (2019)'] = total_data['Total Specialist Physicians (2019)'].apply(lambda x: -118.95 if x < -118.95 else x)

# %%
total_data.describe()
# Out:
#        Median_Household_Income_2018  Percent of Population Aged 60+  \
# count                   3140.000000                     3140.000000
# mean                   52783.187102                       24.736943
# std                    13876.113404                        5.564871
# min                    25385.000000                        5.800000
# 25%                    43680.500000                       21.200000
# 50%                    50564.750000                       24.400000
# 75%                    58822.250000                       27.800000
# max                   140382.000000                       64.200000
#
#         STATE_NAME  anycondition_prevalence  Obesity_prevalence  \
# count  3140.000000              3140.000000         3140.000000
# mean     26.253503                46.793917           35.019299
# std      14.260381                 6.379448            4.517088
# min       0.000000                22.000000           15.200000
# ...

# %%
from sklearn.model_selection import train_test_split

num_variables = [str(i)  for i in total_data.columns]

# We divide the dataset into training and test samples
X = total_data.drop("Heart disease_prevalence", axis = 1)#[num_variables]
y = total_data["Heart disease_prevalence"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 14)

X_train.to_csv(r"/workspaces/regularized-linera-regression/data/interim/X_train.csv", index=False)
# with open("X_train.csv", "w") as f:
#     f.write(y_train)
X_test.to_csv(r"/workspaces/regularized-linera-regression/data/interim/X_test.csv", index=False)
# with open("X_test.csv", "w") as f:
#     f.write(y_test)

# %%
y_test.to_csv(r"/workspaces/regularized-linera-regression/data/interim/y_test.csv", index=False)
y_train.to_csv(r"/workspaces/regularized-linera-regression/data/interim/y_train.csv", index=False)

# %%
X_train
# Out:
#       Median_Household_Income_2018  Percent of Population Aged 60+  \
# 3120                       61773.0                            21.8
# 1849                       60862.0                            18.1
# 2749                       44041.0                            27.8
# 490                        46628.0                            17.4
# 1441                       43478.0                            22.5
# ...                            ...                             ...
# 2375                       58806.0                            36.9
# 2454                       41829.0                            26.3
# 1292                       50374.0                            27.4
# 1368                       57494.0                            24.9
# 2667                       43226.0                            24.4
#
#       STATE_NAME  anycondition_prevalence  Obesity_prevalence  \
# 3120          50                     42.6                32.6
# ...

# %%
y_train
# Out:
# 3120     7.1
# 1849     6.3
# 2749     9.7
# 490      6.9
# 1441     8.7
#         ...
# 2375     9.6
# 2454    10.6
# 1292    10.1
# 1368     6.9
# 2667    10.0
# Name: Heart disease_prevalence, Length: 2512, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
# from pickle import dump

num_variables = [str(i) for i in X_train]

scaler = StandardScaler()
scaler.fit(X_train)

X_train_norm = scaler.transform(X_train)
X_train_norm = pd.DataFrame(X_train_norm, index = X_train.index, columns = num_variables)

X_test_norm = scaler.transform(X_test)
X_test_norm = pd.DataFrame(X_test_norm, index = X_test.index, columns = num_variables)

X_train_norm.to_csv(r"/workspaces/regularized-linera-regression/data/interim/X_train_norm.csv", index=False)
X_test_norm.to_csv(r"/workspaces/regularized-linera-regression/data/interim/X_test_norm.csv", index=False)


X_train_norm
# Out:
#       Median_Household_Income_2018  Percent of Population Aged 60+  \
# 3120                      0.634248                       -0.529815
# 1849                      0.569338                       -1.197818
# 2749                     -0.629173                        0.553432
# 490                      -0.444847                       -1.324197
# 1441                     -0.669287                       -0.403436
# ...                            ...                             ...
# 2375                      0.422846                        2.196358
# 2454                     -0.786780                        0.282620
# 1292                     -0.177941                        0.481216
# 1368                      0.329365                        0.029863
# 2667                     -0.687242                       -0.060408
#
#       STATE_NAME  anycondition_prevalence  Obesity_prevalence  \
# 3120    1.674603                -0.659332           -0.537222
# ...
